# %% [markdown]
# <a href="https://colab.research.google.com/github/thmnmht/ResNet/blob/main/ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import scipy.misc
from tensorflow.keras.applications.resnet_v2 import ResNet50V2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet_v2 import preprocess_input, decode_predictions
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.python.framework.ops import EagerTensor
from matplotlib.pyplot import imshow


# %matplotlib inline

# %%
def identity_block(X, f, filters, training=True, initializer=random_uniform):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to random uniform initializer
    
    Returns:
    X -- output of the identity block, tensor of shape (m, n_H, n_W, n_C)
    """
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = 1, strides = (1,1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training) 
    X = Activation('relu')(X)
    
    ## Second component of main path
    X = Conv2D(filters = F2, kernel_size = f, strides = (1, 1), padding = 'same', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation('relu')(X)

    ## Third component of main path
    X = Conv2D(filters = F3, kernel_size = 1, strides = (1, 1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    
    ## Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
  
    return X

# %%
np.random.seed(1)
X1 = np.ones((1, 4, 4, 3)) * -1
X2 = np.ones((1, 4, 4, 3)) * 1
X3 = np.ones((1, 4, 4, 3)) * 3

X = np.concatenate((X1, X2, X3), axis = 0).astype(np.float32)

A3 = identity_block(X, f=2, filters=[4, 4, 3],
                   initializer=lambda seed=0:constant(value=1),
                   training=False)
print('\033[1mWith training=False\033[0m\n')
A3np = A3.numpy()
print(np.around(A3.numpy()[:,(0,-1),:,:].mean(axis = 3), 5))
resume = A3np[:,(0,-1),:,:].mean(axis = 3)
print(resume[1, 1, 0])

print('\n\033[1mWith training=True\033[0m\n')
np.random.seed(1)
A4 = identity_block(X, f=2, filters=[3, 3, 3],
                   initializer=lambda seed=0:constant(value=1),
                   training=True)
print(np.around(A4.numpy()[:,(0,-1),:,:].mean(axis = 3), 5))
# Out:
# With training=False
#
# [[[  0.        0.        0.        0.     ]
#   [  0.        0.        0.        0.     ]]
#
#  [[192.71236 192.71236 192.71236  96.85619]
#   [ 96.85619  96.85619  96.85619  48.9281 ]]
#
#  [[578.1371  578.1371  578.1371  290.56854]
#   [290.56854 290.56854 290.56854 146.78427]]]
# 96.85619
#
# With training=True
#
# [[[0.      0.      0.      0.     ]
#   [0.      0.      0.      0.     ]]
#
#  [[0.40739 0.40739 0.40739 0.40739]
#   [0.40739 0.40739 0.40739 0.40739]]
#
#  [[4.99991 4.99991 4.99991 3.25948]
#   [3.25948 3.25948 3.25948 2.40739]]]

# %%
def convolutional_block(X, f, filters, s = 2, training=True, initializer=glorot_uniform):
    """
    Implementation of the convolutional block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    s -- Integer, specifying the stride to be used
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to Glorot uniform initializer, 
                   also called Xavier uniform initializer.
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    
    # First component of main path glorot_uniform(seed=0)
    X = Conv2D(filters = F1, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)
    
    ## Second component of main path
    X = Conv2D(filters = F2, kernel_size = f, strides = (1, 1), padding = 'same', kernel_initializer = initializer(seed = 0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation('relu')(X)

    ## Third component of main path
    X = Conv2D(filters = F3, kernel_size = 1, strides = (1, 1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    
    ##### SHORTCUT PATH #####
    X_shortcut = Conv2D(filters = F3, kernel_size = 1, strides = (s, s), padding = 'valid', kernel_initializer = initializer(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3)(X_shortcut, training = training)
    
    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
np.random.seed(1)
#X = np.random.randn(3, 4, 4, 6).astype(np.float32)
X1 = np.ones((1, 4, 4, 3)) * -1
X2 = np.ones((1, 4, 4, 3)) * 1
X3 = np.ones((1, 4, 4, 3)) * 3

X = np.concatenate((X1, X2, X3), axis = 0).astype(np.float32)

A = convolutional_block(X, f = 2, filters = [2, 4, 6], training=False)
print(A[0])

B = convolutional_block(X, f = 2, filters = [2, 4, 6], training=True)
print(B[0])
# Out:
# tf.Tensor(
# [[[0.        0.        0.        0.        0.        0.8323332]
#   [0.        0.        0.        0.        0.        0.8323332]]
#
#  [[0.        0.        0.        0.        0.        0.8323332]
#   [0.        0.        0.        0.        0.        0.8323332]]], shape=(2, 2, 6), dtype=float32)
# tf.Tensor(
# [[[2.988216   0.         0.         0.         0.         0.26929575]
#   [2.3369637  2.6119118  0.         0.         2.902531   1.4064465 ]]
#
#  [[2.9608884  0.8700267  0.18884695 0.         0.         4.2859473 ]
#   [0.39575237 2.4243782  0.         0.         1.4219958  1.7269158 ]]], shape=(2, 2, 6), dtype=float32)

# %%
def ResNet50(input_shape = (64, 64, 3), classes = 6):
    """
    Stage-wise implementation of the architecture of the popular ResNet50:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> FLATTEN -> DENSE 

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], s = 1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])

    ## Stage 3
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], s = 2)
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    
    ## Stage 4
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], s = 2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])

    ## Stage 5
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], s = 2)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])
    
    ## AVGPOOL
    X = AveragePooling2D(pool_size=(2, 2))(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X)

    return model

# %%
model = ResNet50(input_shape = (64, 64, 3), classes = 6)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 70, 70, 3)   0           ['input_1[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 64)   9472        ['zero_padding2d[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_22[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 15, 15, 64)   0           ['activation_18[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 15, 15, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 15, 15, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 15, 15, 64)   36928       ['activation_19[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 15, 15, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 15, 15, 256)  16640       ['activation_20[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 15, 15, 256)  16640       ['max_pooling2d[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 15, 15, 256)  0           ['batch_normalization_25[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_21 (Activation)     (None, 15, 15, 256)  0           ['add_6[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 15, 15, 64)   16448       ['activation_21[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 15, 15, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 15, 15, 64)   36928       ['activation_22[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 15, 15, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 15, 15, 256)  16640       ['activation_23[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 15, 15, 256)  0           ['batch_normalization_29[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_24 (Activation)     (None, 15, 15, 256)  0           ['add_7[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 15, 15, 64)   16448       ['activation_24[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 15, 15, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 15, 15, 64)   36928       ['activation_25[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 15, 15, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 15, 15, 256)  16640       ['activation_26[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 15, 15, 256)  0           ['batch_normalization_32[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 15, 15, 256)  0           ['add_8[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 128)    32896       ['activation_27[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 128)   512         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_28[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 128)   512         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 512)    66048       ['activation_29[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 512)    131584      ['activation_27[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_36[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 8, 8, 512)    0           ['batch_normalization_35[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_30 (Activation)     (None, 8, 8, 512)    0           ['add_9[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 128)    65664       ['activation_30[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 128)   512         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_31[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 128)   512         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 512)    66048       ['activation_32[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_39[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_39[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 8, 8, 512)    0           ['add_10[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 128)    65664       ['activation_33[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 128)   512         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_34[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 128)   512         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 512)    66048       ['activation_35[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_42[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_42[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 8, 8, 512)    0           ['add_11[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 128)    65664       ['activation_36[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 128)   512         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_37[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 128)   512         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 512)    66048       ['activation_38[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_45[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_45[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 512)    0           ['add_12[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 4, 4, 256)    131328      ['activation_39[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_40[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 4, 4, 1024)   263168      ['activation_41[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 4, 4, 1024)   525312      ['activation_39[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_49[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_48[0][0]',
#                                                                   'batch_normalization_49[0][0]']
#
#  activation_42 (Activation)     (None, 4, 4, 1024)   0           ['add_13[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 4, 4, 256)    262400      ['activation_42[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_43[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 4, 4, 1024)   263168      ['activation_44[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_52[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_52[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 4, 4, 1024)   0           ['add_14[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 4, 4, 256)    262400      ['activation_45[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_46[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 4, 4, 1024)   263168      ['activation_47[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_55[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_55[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 4, 4, 1024)   0           ['add_15[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 4, 4, 256)    262400      ['activation_48[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_49[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 4, 4, 1024)   263168      ['activation_50[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_58[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_58[0][0]',
#                                                                   'activation_48[0][0]']
#
#  activation_51 (Activation)     (None, 4, 4, 1024)   0           ['add_16[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 4, 4, 256)    262400      ['activation_51[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_59[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_52[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_60[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 4, 4, 1024)   263168      ['activation_53[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_61[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_61[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 4, 4, 1024)   0           ['add_17[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 4, 4, 256)    262400      ['activation_54[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 4, 4, 256)    590080      ['activation_55[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 4, 4, 256)    0           ['batch_normalization_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 4, 4, 1024)   263168      ['activation_56[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_64[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_64[0][0]',
#                                                                   'activation_54[0][0]']
#
#  activation_57 (Activation)     (None, 4, 4, 1024)   0           ['add_18[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 2, 2, 512)    524800      ['activation_57[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_58[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_66[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 2, 2, 2048)   1050624     ['activation_59[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 2, 2, 2048)   2099200     ['activation_57[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 2, 2, 2048)  8192        ['conv2d_67[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 2, 2, 2048)  8192        ['conv2d_68[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_67[0][0]',
#                                                                   'batch_normalization_68[0][0]']
#
#  activation_60 (Activation)     (None, 2, 2, 2048)   0           ['add_19[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 2, 2, 512)    1049088     ['activation_60[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_69[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_61[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_70[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 2, 2, 2048)   1050624     ['activation_62[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 2, 2, 2048)  8192        ['conv2d_71[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_71[0][0]',
#                                                                   'activation_60[0][0]']
#
#  activation_63 (Activation)     (None, 2, 2, 2048)   0           ['add_20[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 2, 2, 512)    1049088     ['activation_63[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_72[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_72[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 2, 2, 512)    2359808     ['activation_64[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_73[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 2, 2, 512)    0           ['batch_normalization_73[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 2, 2, 2048)   1050624     ['activation_65[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 2, 2, 2048)  8192        ['conv2d_74[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_74[0][0]',
#                                                                   'activation_63[0][0]']
#
#  activation_66 (Activation)     (None, 2, 2, 2048)   0           ['add_21[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 2048)  0           ['activation_66[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 6)            12294       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,546,886
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs = 10, batch_size = 32)

# %%
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
